# %%
import numpy as np
import pandas as pd
grades=pd.Series([85,None,92,45,None,78,55])

# %%
print(grades.isnull())
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
filled_grades=grades.fillna(0)
print(filled_grades)
# Out:
# 0    85.0
# 1     0.0
# 2    92.0
# 3    45.0
# 4     0.0
# 5    78.0
# 6    55.0
# dtype: float64

# %%
# Out:
# 'C:\\Users\\ytaj3'
