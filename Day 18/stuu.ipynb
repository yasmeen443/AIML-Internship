# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import boxcox
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from sklearn.preprocessing import LabelEncoder ,OneHotEncoder

# %%
data=pd.read_csv(r"C:\Users\ytaj3\OneDrive\Desktop\Student_Performance.csv")

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
data.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
data.shape
# Out:
# (10000, 6)

# %%
data.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (9873, 6)

# %%
data.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
data[['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
       'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index']]
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [9873 rows x 6 columns]

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Hours Studied'}>,
#         <Axes: title={'center': 'Previous Scores'}>],
#        [<Axes: title={'center': 'Sleep Hours'}>,
#         <Axes: title={'center': 'Sample Question Papers Practiced'}>],
#        [<Axes: title={'center': 'Performance Index'}>, <Axes: >]],
#       dtype=object)

# %%
encoder=LabelEncoder()

# %%
data["Extracurricular Activities"]=encoder.fit_transform(data['Extracurricular Activities'])

# %%
data.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
plt.figure(figsize=(6,4))
sns.histplot(data['Hours Studied'])
plt.show()

# %%
data['Hours Studied'].skew()
# Out:
# -0.0033483737916364534

# %%
plt.figure(figsize=(6,4))
sns.histplot(data['Previous Scores'])
plt.show()

# %%
data['Previous Scores'].skew()
# Out:
# 0.0055813419610842956

# %%
plt.figure(figsize=(6,4))
sns.histplot(data['Sleep Hours'])
plt.show()

# %%
data['Sleep Hours'].skew()
# Out:
# -0.04134960099660273

# %%
plt.figure(figsize=(6,4))
sns.histplot(data['Sample Question Papers Practiced'])
plt.show()

# %%
data['Sample Question Papers Practiced'].skew()
# Out:
# -0.034893124735861716

# %%
plt.figure(figsize=(6,4))
sns.histplot(data['Performance Index'])
plt.show()

# %%
data['Performance Index'].skew()
# Out:
# -0.00041186196091178305

# %%
data.skew()
# Out:
# Hours Studied                      -0.003348
# Previous Scores                     0.005581
# Extracurricular Activities          0.020059
# Sleep Hours                        -0.041350
# Sample Question Papers Practiced   -0.034893
# Performance Index                  -0.000412
# dtype: float64

# %%
data.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
scaler=StandardScaler()
data["Hours Studied"]=scaler.fit_transform(data[["Hours Studied"]])
data["Previous Scores"]=scaler.fit_transform(data[["Previous Scores"]])
data["Extracurricular Activities"]=scaler.fit_transform(data[["Extracurricular Activities"]])
data["Sleep Hours"]=scaler.fit_transform(data[["Sleep Hours"]])
data["Sample Question Papers Practiced"]=scaler.fit_transform(data[["Sample Question Papers Practiced"]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import mean_squared_error,r2_score

# %%
x=data[['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
       'Sleep Hours', 'Sample Question Papers Practiced']]
y=data[['Performance Index']]

# %%
x.shape,y.shape
# Out:
# ((9873, 5), (9873, 1))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((7898, 5), (1975, 5))

# %%
y_train.shape,y_test.shape
# Out:
# ((7898, 1), (1975, 1))

# %%
x.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0       0.775566         1.706168                    1.010078     1.454025
# 1      -0.383205         0.724912                   -0.990022    -1.491315
# 2       1.161822        -1.064438                    1.010078     0.275889
# 3       0.003052        -1.006717                    1.010078    -0.902247
# 4       0.775566         0.320865                   -0.990022     0.864957
#
#    Sample Question Papers Practiced
# 0                         -1.249715
# 1                         -0.900925
# 2                         -0.900925
# 3                         -0.900925
# 4                          0.145444

# %%
y.head()
# Out:
#    Performance Index
# 0           1.862979
# 1           0.509348
# 2          -0.531907
# 3          -1.000471
# 4           0.561411

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_, model.coef_
# Out:
# (array([-0.00063426]),
#  array([[0.384283  , 0.91859613, 0.01493664, 0.04172256, 0.0281672 ]]))

# %%
predicted_val=model.predict(x_test)

# %%
predicted_val
# Out:
# array([[-0.45485328],
#        [ 1.30514648],
#        [ 0.30449081],
#        ...,
#        [ 1.13849663],
#        [ 1.61551254],
#        [-1.0067534 ]])

# %%
mean_squared_error(y_test,predicted_val)*100 #near 0
# Out:
# 1.1671265615520254

# %%
r2_score(y_test,predicted_val) #near 1
# Out:
# 0.9884301209927054

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial=PolynomialFeatures(degree=2)
poly_features=polynomial.fit_transform(x_train)
model=LinearRegression()
model.fit(poly_features,y_train)
# Out:
# LinearRegression()

# %%
model.coef_,model.intercept_
# Out:
# (array([[ 0.00000000e+00,  3.84239946e-01,  9.18627093e-01,
#           1.56849991e+06,  4.17908263e-02,  2.81742242e-02,
#           1.15225437e-03,  1.76352844e-05,  9.42567593e-04,
#           2.23901594e-03,  9.57904360e-04, -1.17110327e-03,
#           1.06737523e-03,  5.14524782e-04, -1.05605918e-03,
#          -7.82071761e+07, -4.85044368e-04, -1.18872009e-03,
#           1.30341023e-03,  1.25105079e-03,  9.70554421e-05]]),
#  array([78207176.12478106]))

# %%
test_features=polynomial.fit_transform(x_test)

# %%
pred=model.predict(test_features)

# %%
from sklearn.svm import SVC,SVR
