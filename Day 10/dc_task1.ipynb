# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ytaj3\OneDrive\Desktop\Internship\AIML-Internship\Day 10\customer_orders.csv")
df
# Out:
#     order_id customer_id   amount  quantity     status
# 0     1001.0        C001   2500.0       2.0  Delivered
# 1     1002.0        C002   1800.0       1.0    Shipped
# 2     1003.0        C003      NaN       3.0  Delivered
# 3     1004.0        C004   5200.0       5.0  Cancelled
# 4     1005.0        C005   3000.0       NaN  Delivered
# 5     1002.0        C002   1800.0       1.0    Shipped
# 6        NaN        C006   4500.0       2.0  Delivered
# 7     1007.0        C007  12000.0       1.0  Delivered
# 8     1008.0        C008    700.0       4.0   Returned
# 9     1009.0        C009   2500.0       2.0  Delivered
# 10    1010.0        C010      NaN       1.0    Shipped
# 11    1004.0        C004   5200.0       5.0  Cancelled

# %%
df.shape
# Out:
# (12, 5)

# %%
df.isna().sum()
# Out:
# order_id       1
# customer_id    0
# amount         2
# quantity       1
# status         0
# dtype: int64

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
numeric_cols
# Out:
# Index(['order_id', 'amount', 'quantity'], dtype='object')

# %%
df[numeric_cols]
# Out:
#     order_id   amount  quantity
# 0     1001.0   2500.0       2.0
# 1     1002.0   1800.0       1.0
# 2     1003.0   2750.0       3.0
# 3     1004.0   5200.0       5.0
# 4     1005.0   3000.0       2.0
# 5     1002.0   1800.0       1.0
# 6     1004.0   4500.0       2.0
# 7     1007.0  12000.0       1.0
# 8     1008.0    700.0       4.0
# 9     1009.0   2500.0       2.0
# 10    1010.0   2750.0       1.0
# 11    1004.0   5200.0       5.0

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     order_id customer_id   amount  quantity     status
# 0     1001.0        C001   2500.0       2.0  Delivered
# 1     1002.0        C002   1800.0       1.0    Shipped
# 2     1003.0        C003   2750.0       3.0  Delivered
# 3     1004.0        C004   5200.0       5.0  Cancelled
# 4     1005.0        C005   3000.0       2.0  Delivered
# 6     1004.0        C006   4500.0       2.0  Delivered
# 7     1007.0        C007  12000.0       1.0  Delivered
# 8     1008.0        C008    700.0       4.0   Returned
# 9     1009.0        C009   2500.0       2.0  Delivered
# 10    1010.0        C010   2750.0       1.0    Shipped

# %%
df = df.drop_duplicates("order_id")

# %%
df
# Out:
#     order_id customer_id   amount  quantity     status
# 0     1001.0        C001   2500.0       2.0  Delivered
# 1     1002.0        C002   1800.0       1.0    Shipped
# 2     1003.0        C003   2750.0       3.0  Delivered
# 3     1004.0        C004   5200.0       5.0  Cancelled
# 4     1005.0        C005   3000.0       2.0  Delivered
# 7     1007.0        C007  12000.0       1.0  Delivered
# 8     1008.0        C008    700.0       4.0   Returned
# 9     1009.0        C009   2500.0       2.0  Delivered
# 10    1010.0        C010   2750.0       1.0    Shipped
